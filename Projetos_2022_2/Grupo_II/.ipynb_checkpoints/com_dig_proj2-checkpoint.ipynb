# %%
import numpy as np
import random
import commlib
import channels
from matplotlib import pyplot as plt
from locale import windows_locale

# %%
Nsym = 50 #numero de bits
fc = 400
fs = 200e3
M = 4 
k = np.log2(M)
ctl_phase=np.pi/4
bitrate=100
bitstream = [random.randint(0,1) for e in range(Nsym*int(k))]
txsignals=commlib.MPSK_mod(bitstream, bitrate, fc, fs, M, ctl_phase, False, plt_ctln=True, plt_signals=True)
print(txsignals)
# Out:
# [array([0.00000e+00, 5.00000e-06, 1.00000e-05, ..., 9.99985e-01,
#        9.99990e-01, 9.99995e-01]), array([0.70710678, 0.71593648, 0.72465313, ..., 0.67995338, 0.68911381,
#        0.69816542]), None, array([-0.0499875, -0.0499875, -0.0499875, ..., -0.0499875, -0.0499875,
#        -0.0499875]), None]
